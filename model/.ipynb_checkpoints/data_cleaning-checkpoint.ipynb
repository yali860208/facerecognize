# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# %matplotlib inline:<br>
# Magic Functions 在 IPython 獨有，將matplotlib的圖表直接嵌入到Notebook之中，可省略 plt.show()

# %% [markdown]
# ## 顯示圖片

# %%
img = cv2.imread('./test_images/onew_58.jpg')
img.shape
# Out:
# (2048, 1152, 3)

# %%
img
# Out:
# array([[[204, 186, 187],
#         [205, 187, 188],
#         [206, 188, 189],
#         ...,
#         [207, 199, 199],
#         [207, 199, 199],
#         [207, 199, 199]],
#
#        [[205, 187, 188],
#         [206, 188, 189],
#         [206, 188, 189],
#         ...,
#         [207, 199, 199],
#         [207, 199, 199],
#         [207, 199, 199]],
#
#        [[206, 188, 189],
#         [206, 188, 189],
#         [207, 189, 190],
#         ...,
#         [207, 199, 199],
#         [207, 199, 199],
#         [207, 199, 199]],
#
#        ...,
#
#        [[172, 155, 159],
#         [172, 155, 159],
#         [172, 155, 159],
#         ...,
#         [ 44,  25,  34],
#         [ 44,  25,  34],
#         [ 43,  24,  33]],
#
#        [[169, 152, 156],
#         [170, 153, 157],
#         [171, 154, 158],
#         ...,
#         [ 44,  25,  34],
#         [ 44,  25,  34],
#         [ 43,  24,  33]],
#
#        [[167, 150, 154],
#         [168, 151, 155],
#         [170, 153, 157],
#         ...,
#         [ 44,  25,  34],
#         [ 44,  25,  34],
#         [ 43,  24,  33]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # cv2.cvtColor : 色彩空間轉化函數 # BGR to GRAY : opencv 預設為 BGR
gray.shape
# Out:
# (2048, 1152)

# %%
gray
# Out:
# array([[188, 189, 190, ..., 200, 200, 200],
#        [189, 190, 190, ..., 200, 200, 200],
#        [190, 190, 191, ..., 200, 200, 200],
#        ...,
#        [158, 158, 158, ...,  30,  30,  29],
#        [155, 156, 157, ...,  30,  30,  29],
#        [153, 154, 156, ...,  30,  30,  29]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')  # cmap(colormap) : 顏色圖譜

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
hsv.shape
# Out:
# (1200, 975, 3)

# %%
plt.imshow(hsv, cmap='hsv')

# %% [markdown]
# ## 偵測臉和眼睛

# %% [markdown]
# Haar 特徵分類器，描述人體各部位的 Haar 特徵值，包含 face, eyes, lips 等等

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 1) # (image,scaleFacter每次窗口要移多大,minNeighbors檢測幾次才確定為人臉)
faces # 返回 [x座標, y座標, 寬度, 高度]
# Out:
# array([[840, 791, 196, 196]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (840, 791, 196, 196)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2) # (影像,頂點座標,對向頂點座標,顏色,線條寬度)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows() # 關閉所有 openCV 視窗
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray,1.1,1) # 用灰階找目標，省時間
    print(eyes)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2) # 畫在彩色上
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()
# Out:
# ()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %% [markdown]
# ## 函數 : 選出能找到兩個眼睛的照片

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 6)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 6)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/mh_78.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/onew_14.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# ## 挑選符合有兩眼的圖片進 cropped 資料夾

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/jonghyun',
#  './dataset/key',
#  './dataset/minho',
#  './dataset/onew',
#  './dataset/taemin']

# %%
# 建 cropped 資料夾
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
name_dict = {}
for img_dir in img_dirs:
    name = img_dir.split('/')[-1]
# Out:
# jonghyun
# key
# minho
# onew
# taemin

# %%
from notebook.services.config import ConfigManager
c = ConfigManager()
c.update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": True}}})
# Out:
# {'CodeCell': {'cm_config': {'autoCloseBrackets': True}}}
